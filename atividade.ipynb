# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]

plt.plot(x, y)
plt.title("Gráfico de teste")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
print("Olá, Jupyter Notebook no VS Code!")
